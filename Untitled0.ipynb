# %%
import requests
import json
import pandas as pd

data_dict = {}
id = 0
num = 20
for id in range(0,num):
  res = requests.get('https://randomuser.me/api')
  response = json.loads(res.text)
  results  = response['results']
  for i in range(len(results)):
    data_dict[id] = {}
    data_dict[id]['first_name'] = results[i]['name']['first']
    data_dict[id]['last_name'] = results[i]['name']['last']
    data_dict[id]['gender (actual)'] = results[i]['gender']
  id += 1

actual_df = pd.DataFrame.from_dict(data_dict, orient='index')
actual_df
# Out:
#      first_name  last_name gender (actual)
# 0          Afre   de Souza            male
# 1         Selma   Andersen          female
# 2      Samantha    Hawkins          female
# 3     Salvatore       Noel            male
# 4          آوین    نكو نظر          female
# 5         Meral      Çetin          female
# 6           Eva     Robert          female
# 7      Parcidio      Nunes            male
# 8          Thea   Johansen          female
# 9          Rosa  Domínguez          female
# 10      Tihomir      Rađen            male
# 11         Leon       Boyd            male
# 12        Craig    Daniels            male
# 13          Leo     French            male
# 14  Christoffer   Andersen            male
# 15     Ludmilla      Grimm          female
# 16       Toledo      Alves            male
# 17       Nathan     Garcia            male
# 18        Doris    Lambert          female
# 19       Gökhan     Tokgöz            male

# %%
name_list = []
for name in actual_df['first_name']:
  name_list.append(name)

pred_dict = {}
for i in range(len(actual_df)):
  url = 'https://api.genderize.io/?name=' + name_list[i]
  res = requests.get(url)
  response = json.loads(res.text)
  pred_dict[i] = {}
  pred_dict[i]['gender (predict)'] = response['gender']
  pred_dict[i]['probability'] = response['probability']

pred_df = pd.DataFrame.from_dict(pred_dict, orient='index')
pred_df
# Out:
#    gender (predict)  probability
# 0              male         0.88
# 1            female         0.99
# 2            female         1.00
# 3              male         1.00
# 4              None         0.00
# 5            female         0.98
# 6            female         0.99
# 7              male         1.00
# 8            female         1.00
# 9            female         1.00
# 10             male         1.00
# 11             male         1.00
# 12             male         1.00
# 13             male         0.98
# 14             male         1.00
# 15           female         1.00
# 16           female         0.84
# 17             male         1.00
# 18           female         1.00
# 19             male         1.00

# %%
result_df = actual_df.join(pred_df)
result_df['same_gender'] = (result_df['gender (actual)'] == result_df['gender (predict)'])
result_df
# Out:
#      first_name  last_name gender (actual) gender (predict)  probability  \
# 0          Afre   de Souza            male             male         0.88
# 1         Selma   Andersen          female           female         0.99
# 2      Samantha    Hawkins          female           female         1.00
# 3     Salvatore       Noel            male             male         1.00
# 4          آوین    نكو نظر          female             None         0.00
# 5         Meral      Çetin          female           female         0.98
# 6           Eva     Robert          female           female         0.99
# 7      Parcidio      Nunes            male             male         1.00
# 8          Thea   Johansen          female           female         1.00
# 9          Rosa  Domínguez          female           female         1.00
# 10      Tihomir      Rađen            male             male         1.00
# 11         Leon       Boyd            male             male         1.00
# 12        Craig    Daniels            male             male         1.00
# 13          Leo     French            male             male         0.98
# 14  Christoffer   Andersen            male             male         1.00
# 15     Ludmilla      Grimm          female           female         1.00
# 16       Toledo      Alves            male           female         0.84
# 17       Nathan     Garcia            male             male         1.00
# 18        Doris    Lambert          female           female         1.00
# 19       Gökhan     Tokgöz            male             male         1.00
#
#     same_gender
# 0          True
# 1          True
# 2          True
# 3          True
# 4         False
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10         True
# 11         True
# 12         True
# 13         True
# 14         True
# 15         True
# 16        False
# 17         True
# 18         True
# 19         True

# %%
name_list = []
for name in df['first_name']:
  name_list.append(name)

for i in range(len(df)):
  print(name_list[i])
# Out:
# Constance
# Mar
# فاطمه
# Kunigunda
# Jorge
# Barış
# Rebecca
# Megan
# Procópio
# Robert
# Veronica
# Stozhar
# یلدا
# Ephraim
# Oona
# Guntram
# Jack
# Elya
# سارا
# Nalan

# %%
res = requests.get('https://api.genderize.io/?name=Lucena')
response = json.loads(res.text)
print(response)
# Out:
# {'count': 514, 'name': 'Lucena', 'gender': 'female', 'probability': 0.96}
